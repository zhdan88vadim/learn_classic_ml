# %%
dial_codes = [                                                  # <1>
    (880, 'Bangladesh'),
    (55,  'Brazil'),
    (86,  'China'),
    (91,  'India'),
    (62,  'Indonesia'),
    (81,  'Japan'),
    (234, 'Nigeria'),
    (92,  'Pakistan'),
    (7,   'Russia'),
    (1,   'United States'),
]

dic = {value.upper():key for key, value in dial_codes if key > 10}
print(dic)
# Out:
# {'BANGLADESH': 880, 'BRAZIL': 55, 'CHINA': 86, 'INDIA': 91, 'INDONESIA': 62, 'JAPAN': 81, 'NIGERIA': 234, 'PAKISTAN': 92}
